# %% [markdown]
# # Code-along · Where this runs in your organisation
#
# Nothing in this notebook is expected to produce a model answer today. It needs
# a project, an identity, and a role that someone else grants. Reading it is the
# exercise.

# %%
from runpy import run_path

snippet = run_path("07_cloud_hosted_models.py")

# %% [markdown]
# ## Explore
#
# 1. Compare the function below with `call_gemini` in `01_closed_model_call.py`.
#    The model, the prompt, and the returned text are identical.
# 2. Exactly one thing changed: who vouches for the caller. Name it.
# 3. Which of the two can your organisation revoke without touching your code?
# 4. Write down what you would have to request from your platform team to make
#    this run. That list is the real content of this section.

# %%
import inspect
import os

for name in ("GOOGLE_CLOUD_PROJECT", "HF_TOKEN"):
    value = os.getenv(name) or "(unset -- ask your platform team)"
    print(f"{name:<22} {value}")

print()
print(inspect.getsource(snippet["call_vertex"]))
