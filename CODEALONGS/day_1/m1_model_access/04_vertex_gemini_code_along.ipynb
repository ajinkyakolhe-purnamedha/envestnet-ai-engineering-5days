# %% [markdown]
# # Code-along · Gemini through Vertex AI
#
# The task stays the same. The identity and governance boundary change.

# %%
from runpy import run_path
run_path("03_vertex_gemini.py")

# %% [markdown]
# ## Explore
#
# Compare direct API-key access with a cloud project and IAM identity. Which identity should a production workload use?

# %%
import os
print({"project": os.getenv("GOOGLE_CLOUD_PROJECT"), "location": "global"})
