# %% [markdown]
# # Code-along · Local open weights
#
# This begins with the exact snippet. Run it once online and once with Wi-Fi off.

# %%
from runpy import run_path
run_path("07_local_model.py")

# %% [markdown]
# ## Explore
#
# The model is a folder of local files. The next module explains why its small size affects capability, latency, and quality.

# %%
from pathlib import Path
print([path.name for path in Path("../../../OFFLINE-AI-Models/smollm2-135m-instruct").glob("*.json")])
