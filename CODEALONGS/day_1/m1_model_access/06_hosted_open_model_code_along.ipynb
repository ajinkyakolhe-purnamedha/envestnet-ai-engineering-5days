# %% [markdown]
# # Code-along · Hosted open-weight models
#
# Start with a text model; then use model cards to choose a task-specific model.

# %%
from runpy import run_path
run_path("05_hosted_open_model.py")

# %% [markdown]
# ## Optional capability demos
#
# Use a hosted Hugging Face model or Space to demonstrate speech-to-text and text-to-image. These are instructor-prepared demonstrations: model availability and authentication change frequently.

# %%
tasks = ["speech to text", "text to image", "embeddings"]
print("Choose a specialist model for:", tasks)
