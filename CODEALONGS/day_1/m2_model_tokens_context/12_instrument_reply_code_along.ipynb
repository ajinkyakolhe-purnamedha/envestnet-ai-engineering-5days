# %% [markdown]
# # Code-along · Instrument one reply
#
# A cost estimate is application data, not a guess after the fact.

# %%
from runpy import run_path
run_path("11_instrument_reply.py")

# %% [markdown]
# ## Explore
#
# 1. Double input tokens only. What changes?
# 2. Add two call estimates to a cumulative total.
# 3. Where would real usage metadata enter this function?

# %%
calls = [(200, 50), (500, 100)]
total = sum(estimate_cost(i, o, 0.002, 0.004) for i, o in calls)
print(f"cumulative=${total:.6f}")
