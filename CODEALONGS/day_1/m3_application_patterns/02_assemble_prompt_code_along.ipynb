# %% [markdown]
# # Code-along · Assemble a prompt
#
# Keep the parts separate before the model receives one string.

# %%
from runpy import run_path
run_path("01_assemble_prompt.py")

# %% [markdown]
# ## Explore
#
# 1. Replace the context with a different portfolio fact.
# 2. Which component would you inspect if the tone is wrong?
# 3. Which component would you inspect if the fact is wrong?

# %%
print(assemble_prompt("Use bullets.", "SPY is 52%.", "Name one risk."))
