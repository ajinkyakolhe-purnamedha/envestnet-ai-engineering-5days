# %% [markdown]
# # Code-along · Deterministic contract
#
# A valid schema is not permission to make a business action.

# %%
from runpy import run_path
run_path("09_test_contract.py")

# %% [markdown]
# ## Explore
#
# 1. Test an allowed symbol at 35%.
# 2. Test an unknown symbol.
# 3. Why should an LLM not be the final judge of this limit?

# %%
for allocation in (35, 36):
    print(allocation, validate_trade_request({"symbol": "SPY", "allocation_percent": allocation}))
