# %% [markdown]
# # Code-along · Choose the first rung
#
# Name the requirement before naming a framework.

# %%
from runpy import run_path
run_path("07_choose_pattern.py")

# %% [markdown]
# ## Explore
#
# 1. Classify a private, changing policy question.
# 2. Classify a stable high-volume extraction workflow.
# 3. Why does a dynamic multi-step task not start with an agent automatically?

# %%
cases = [{"private_facts"}, {"repeated_behavior"}, {"dynamic_steps"}]
for requirements in cases:
    print(requirements, choose_pattern(requirements))
