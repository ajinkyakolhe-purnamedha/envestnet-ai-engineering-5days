# %% [markdown]
# # Code-along · A maintainable model boundary
#
# Begin with the exact boundary. Then connect it to a real provider without leaking provider details through the application.

# %%
from runpy import run_path
run_path("09_model_boundary.py")

# %% [markdown]
# ## Explore
#
# 1. Replace the lambda with a Gemini call.
# 2. Log duration and model ID.
# 3. Test the empty-response path without making a network call.

# %%
from pathlib import Path
from runpy import run_path
reply_to_advisor = run_path("09_model_boundary.py")["reply_to_advisor"]
assert reply_to_advisor("hello", lambda _: "") == "I could not produce an answer. Please try again."
