# %% [markdown]
# # Code-along · Token IDs
#
# A token is a model-specific text chunk, not a word.

# %%
from runpy import run_path
run_path("03_token_ids.py")

# %% [markdown]
# ## Explore
#
# 1. Encode a ticker, a sentence and a line of code.
# 2. Which is longest in characters? Which is longest in tokens?
# 3. Why should you not use this local count as a provider invoice?

# %%
examples = ["AAPL", "Diversify the portfolio.", "allocation_percent = 52"]
for text in examples:
    print(text, len(tokenizer.encode(text)))
