# %% [markdown]
# # Code-along · Direct call
#
# A general model can draft language; it does not automatically know your private facts.

# %%
from runpy import run_path
run_path("03_base_call.py")

# %% [markdown]
# ## Explore
#
# 1. Change the rewriting task.
# 2. Ask for a current internal policy answer. What is missing?
# 3. Which next pattern adds that missing ingredient?

# %%
print(direct_answer("Make this client note friendlier."))
