# %% [markdown]
# # Code-along · Meaning similarity
#
# Vectors are a preview of how later retrieval can find related text.

# %%
from runpy import run_path
run_path("09_embedding_similarity.py")

# %% [markdown]
# ## Explore
#
# 1. Compare a concentration vector with a tax vector.
# 2. Rank three synthetic policy chunks against a query vector.
# 3. What does this score not prove about factual correctness?

# %%
chunks = {"concentration": [0.8, 0.2, 0.0], "tax": [0.0, 0.1, 0.9], "cash": [0.2, 0.7, 0.1]}
print(sorted(((cosine(concentration_risk, vector), name) for name, vector in chunks.items()), reverse=True))
