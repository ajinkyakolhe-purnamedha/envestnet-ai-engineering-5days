# %% [markdown]
# # Code-along · Gemini text
#
# Start with the exact cookbook snippet. Then change one instruction at a time and observe how the output changes.

# %%
from runpy import run_path
run_path("01_gemini_text.py")

# %% [markdown]
# ## Explore
#
# 1. Put the portfolio fact in a variable.
# 2. Ask for one sentence, then three bullets.
# 3. What makes an instruction specific enough to evaluate?

# %%
note = "Cash is 40% of the book; AAPL is 52%."
prompt = f"Explain the biggest concentration risk in one sentence: {note}"
print(prompt)
