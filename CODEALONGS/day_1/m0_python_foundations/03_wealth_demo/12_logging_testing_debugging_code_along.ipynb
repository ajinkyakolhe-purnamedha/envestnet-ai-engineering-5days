# %% [markdown]
# # Logging, testing, and debugging
#
# Logs tell you what happened; tests tell you whether it is still correct.

# %%
import logging


logging.basicConfig(level=logging.INFO, format="%(levelname)s | %(message)s")
logger = logging.getLogger(__name__)

selected_date = "2020-06-01"
logger.info("Selected %s price dated %s", "AAPL", selected_date)
print(f"Selected AAPL price dated {selected_date}")

# Run: python -m unittest wealth_demo.test_wealth_demo -v
# Use breakpoint() to pause locally, then read tracebacks from the bottom up.
breakpoint  # breakpoint() is available when you need an interactive inspection.

# %% [markdown]
# Run `python -m unittest wealth_demo.test_wealth_demo -v`. The price test protects the rule: choose the last price on or before the requested date.

# %%
# Deliberate bug:
# WHERE symbol = ? AND date >= ? ORDER BY date ASC LIMIT 1
#
# Fix it to:
# WHERE symbol = ? AND date <= ? ORDER BY date DESC LIMIT 1

# %% [markdown]
# **Debugging exercise:** read the failed assertion, inspect the INFO log's selected date, correct the query, and rerun the test. Use `breakpoint()` only when the log and test are not enough.
