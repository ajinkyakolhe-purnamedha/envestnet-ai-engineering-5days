# %% [markdown]
# # Functions
#
# Start with one reusable calculation.

# %%
def purchase_cost(shares: int, price: float) -> float:
    """Return the cost of buying shares at a price."""
    if shares <= 0 or price <= 0:
        raise ValueError("Shares and price must be positive.")
    return shares * price


print(f"Purchase cost: {purchase_cost(10, 80.50)}")

# %% [markdown]
# **Your turn:** call the function for 25 shares. Then try zero shares and read the error.

# %%
def gain_loss(cost: float, value: float) -> float:
    """Return the gain or loss relative to purchase cost."""
    return value - cost

print(gain_loss(805.0, 850.0))

# %% [markdown]
# Checklist: one job, descriptive name, type hints, docstring, return value, and a clear invalid-input error.
