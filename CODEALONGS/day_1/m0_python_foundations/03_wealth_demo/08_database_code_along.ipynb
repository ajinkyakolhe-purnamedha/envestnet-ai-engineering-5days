# %% [markdown]
# # SQLite storage
#
# Start by asking one safe historical-price question.

# %%
import sqlite3


connection = sqlite3.connect(":memory:")
connection.execute("CREATE TABLE prices (symbol TEXT, date TEXT, close REAL)")
connection.execute("INSERT INTO prices VALUES (?, ?, ?)", ("AAPL", "2020-06-01", 80.46))
row = connection.execute(
    "SELECT close FROM prices WHERE symbol = ? AND date <= ? "
    "ORDER BY date DESC LIMIT 1",
    ("AAPL", "2020-06-01"),
).fetchone()
print(f"AAPL close on 2020-06-01: {row[0]}")

# %% [markdown]
# **Your turn:** insert a second date and request the first date again. Why is `date <= ?` important?

# %%
connection.execute("CREATE TABLE holdings (symbol TEXT, shares INTEGER, purchase_price REAL)")
connection.execute("INSERT INTO holdings VALUES (?, ?, ?)", ("AAPL", 10, 80.50))
print(connection.execute("SELECT * FROM holdings").fetchall())

# %% [markdown]
# Use `?` parameters for every value. Never create SQL by joining or f-stringing user data.
