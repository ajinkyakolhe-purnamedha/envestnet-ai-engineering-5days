# %% [markdown]
# # Classes
#
# A holding keeps related data and behavior together.

# %%
from dataclasses import dataclass


@dataclass
class Holding:
    symbol: str
    shares: int
    purchase_price: float

    def market_value(self, latest_price: float) -> float:
        """Return this holding's current market value."""
        return self.shares * latest_price


holding = Holding("AAPL", 10, 80.50)
print(f"{holding.symbol} market value: {holding.market_value(82.50)}")

# %% [markdown]
# **Your turn:** make a second holding and call its method.

# %%
cash = 1_000.0
cost = holding.shares * holding.purchase_price
if cost > cash:
    raise ValueError("Not enough cash")
cash -= cost
print(cash)

# %% [markdown]
# Next, `Portfolio` turns this cash rule into a method. The class exists because data and its rule now belong together.
