# %% [markdown]
# # Code-along · Prompted extraction
#
# A schema shapes output; Python still owns business policy.

# %%
from runpy import run_path
run_path("05_prompted_extraction.py")

# %% [markdown]
# ## Explore
#
# 1. Try zero shares. What rejects it?
# 2. Add an allocation percentage of 36. Does this schema know the policy cap?
# 3. Where should that policy check live?

# %%
from pydantic import ValidationError
try:
    TradeIntent(action="buy", symbol="SPY", shares=0)
except ValidationError as error:
    print(error.errors()[0]["msg"])
