# %% [markdown]
# # Variables and type hints
#
# Predict the cost before you run each cell.

# %%
symbol: str = "AAPL"
shares: int = 10
purchase_price: float = 80.50

purchase_cost: float = shares * purchase_price
print(f"{symbol} purchase cost: {purchase_cost}")

# %% [markdown]
# **Your turn:** change `shares` to 25. What changes, and what does not?

# %%
latest_price: float = 82.50
current_value = shares * latest_price
print(current_value)

# %% [markdown]
# Type hints document the values that cross a boundary. Obvious temporary values do not all need annotations.
