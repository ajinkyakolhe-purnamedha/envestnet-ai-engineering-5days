# %% [markdown]
# # Code-along · Count context
#
# Start with one request, then identify what makes it grow.

# %%
from runpy import run_path
run_path("05_count_context.py")

# %% [markdown]
# ## Explore
#
# 1. Add a standing instruction. What changed?
# 2. Add two history turns. What changed?
# 3. Which count belongs in an estimate and which count belongs in the provider response?

# %%
history = "User: What do I hold? Assistant: AAPL is 52%."
full_prompt = prompt + " " + history
print(len(full_prompt.split()))
